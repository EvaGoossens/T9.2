# %% [markdown]
# # Datenanalyse: Seattle Library Checkouts

# %%
# Libraries importieren
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkouts_file = "checkouts.csv"

# %%
# Download der Daten
urllib.request.urlretrieve (url, checkouts_file)
# Out:
# ('checkouts.csv', <http.client.HTTPMessage at 0x28bb2063108>)

# %%
#Anzeigen der Tabelle mit Pandas
checkouts = pd.read_csv(checkouts_file)

# %%
checkouts
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 1      Physical      Horizon         BOOK          2018             12
# 2      Physical      Horizon    SOUNDDISC          2018             12
# 3      Physical      Horizon         BOOK          2018             12
# 4      Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2018             12
# 9996    Digital    OverDrive        EBOOK          2018             12
# 9997    Digital    OverDrive        EBOOK          2018             12
# 9998   Physical      Horizon    VIDEODISC          2018             12
# 9999   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
# Anzeigen der Spaltennamen
print(checkouts.columns)
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %% [markdown]
# ## Wie viele Checkouts gab es insgesamt?

# %%
checkouts["checkouts"].sum()
# Out:
# 34686

# %% [markdown]
# ## Welche Medienarten kommen wie häufig vor?

# %%
# Spalte "materialtype" anzeigen
print(checkouts[["materialtype"]])
# Out:
#      materialtype
# 0            BOOK
# 1            BOOK
# 2       SOUNDDISC
# 3            BOOK
# 4            BOOK
# ...           ...
# 9995         BOOK
# 9996        EBOOK
# 9997        EBOOK
# 9998    VIDEODISC
# 9999         BOOK
#
# [10000 rows x 1 columns]

# %%
# Gruppieren nach materialtype + Anzahl
checkouts.groupby("materialtype")["materialtype"].count()
# Out:
# materialtype
# AUDIOBOOK               1035
# BOOK                    4573
# CR                         6
# EBOOK                   2535
# ER                         6
# ER, SOUNDDISC              2
# LARGEPRINT                 4
# MAGAZINE                   6
# MIXED                      2
# MUSIC                     27
# REGPRINT                  18
# SOUNDDISC                888
# SOUNDDISC, VIDEODISC      13
# SOUNDREC                   5
# VIDEO                      6
# VIDEODISC                874
# Name: materialtype, dtype: int64

# %%
# Histogramm
checkouts.groupby("materialtype")["materialtype"].hist()
# Out:
# materialtype
# AUDIOBOOK               AxesSubplot(0.125,0.125;0.775x0.755)
# BOOK                    AxesSubplot(0.125,0.125;0.775x0.755)
# CR                      AxesSubplot(0.125,0.125;0.775x0.755)
# EBOOK                   AxesSubplot(0.125,0.125;0.775x0.755)
# ER                      AxesSubplot(0.125,0.125;0.775x0.755)
# ER, SOUNDDISC           AxesSubplot(0.125,0.125;0.775x0.755)
# LARGEPRINT              AxesSubplot(0.125,0.125;0.775x0.755)
# MAGAZINE                AxesSubplot(0.125,0.125;0.775x0.755)
# MIXED                   AxesSubplot(0.125,0.125;0.775x0.755)
# MUSIC                   AxesSubplot(0.125,0.125;0.775x0.755)
# REGPRINT                AxesSubplot(0.125,0.125;0.775x0.755)
# SOUNDDISC               AxesSubplot(0.125,0.125;0.775x0.755)
# SOUNDDISC, VIDEODISC    AxesSubplot(0.125,0.125;0.775x0.755)
# SOUNDREC                AxesSubplot(0.125,0.125;0.775x0.755)
# VIDEO                   AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
# Wie bekomme ich das leserlich?

# %% [markdown]
# ## Welche Medienarten wurden wie häufig ausgeliehen?

# %%
# Anzeigen der unter materialtype vorhandenen Kategorien + Summe der Checkouts
checkouts.groupby(['materialtype']).sum()
# Out:
#                       checkoutyear  checkoutmonth  checkouts
# materialtype
# AUDIOBOOK                  2088630          12420       4593
# BOOK                       9228314          54876      14497
# CR                           12108             72         19
# EBOOK                      5115630          30420       7745
# ER                           12108             72          9
# ER, SOUNDDISC                 4036             24          4
# LARGEPRINT                    8072             48          9
# MAGAZINE                     12108             72        254
# MIXED                         4036             24         18
# MUSIC                        54486            324         31
# REGPRINT                     36324            216         70
# SOUNDDISC                  1791984          10656       1852
# SOUNDDISC, VIDEODISC         26234            156         28
# SOUNDREC                     10090             60          7
# ...

# %%
# Plotten eines Histogramms
checkouts["materialtype"].hist()

# %% [markdown]
# ## Welche Medien hatten weniger als 3 checkouts?

# %%
# Sortieren nach Anzahl der checkouts
checkouts.sort_values(["checkouts"])
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 5514   Physical      Horizon    VIDEODISC          2018             12
# 5512   Physical      Horizon         BOOK          2018             12
# 5511   Physical      Horizon         BOOK          2018             12
# 5504   Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 3068   Physical      Horizon    VIDEODISC          2018             12
# 5313    Digital    OverDrive    AUDIOBOOK          2018             12
# 6495   Physical      Horizon         BOOK          2018             12
# 7623    Digital    OverDrive    AUDIOBOOK          2018             12
# 7257   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
print(checkouts ["checkouts"] <= 2)
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 9995     True
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: checkouts, Length: 10000, dtype: bool

# %%
# Wie kann ich die Tabelle nach values <= 2 filtern?

# %% [markdown]
# ## Welche Bücher wurden besonders häufig ausgeliehen?

# %%
# Welche der Checkouts sind Bücher?
checkouts.loc[checkouts['materialtype'] == "BOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 1      Physical      Horizon         BOOK          2018             12
# 4      Physical      Horizon         BOOK          2018             12
# 5      Physical      Horizon         BOOK          2018             12
# 6      Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9989   Physical      Horizon         BOOK          2018             12
# 9990   Physical      Horizon         BOOK          2018             12
# 9994   Physical      Horizon         BOOK          2018             12
# 9997   Physical      Horizon         BOOK          2018             12
# 9999   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
# Welche davon wurden 50 Mal oder häufiger ausgeliehen?
checkouts.loc[ (checkouts['materialtype'] == "BOOK") & (checkouts["checkouts"] >= 50)]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 508    Physical      Horizon         BOOK          2018             12
# 2914   Physical      Horizon         BOOK          2018             12
# 3194   Physical      Horizon         BOOK          2018             12
# 3354   Physical      Horizon         BOOK          2018             12
# 4055   Physical      Horizon         BOOK          2018             12
# 5027   Physical      Horizon         BOOK          2018             12
# 6120   Physical      Horizon         BOOK          2018             12
# 6495   Physical      Horizon         BOOK          2018             12
# 6616   Physical      Horizon         BOOK          2018             12
# 7170   Physical      Horizon         BOOK          2018             12
# 7257   Physical      Horizon         BOOK          2018             12
# 8285   Physical      Horizon         BOOK          2018             12
# ...

# %%
# Kann man filtern, welche 20 Bücher am häufigsten ausgeliehen wurden?

# %% [markdown]
# ## Welche der physischen Medien sind keine Bücher?

# %%
# Filtern nach usageclass: Physical
checkouts.loc[checkouts['usageclass'] == "Physical"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 1      Physical      Horizon         BOOK          2018             12
# 2      Physical      Horizon    VIDEODISC          2018             12
# 4      Physical      Horizon         BOOK          2018             12
# 5      Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon    SOUNDDISC          2018             12
# 9996   Physical      Horizon    VIDEODISC          2018             12
# 9997   Physical      Horizon         BOOK          2018             12
# 9998   Physical      Horizon    VIDEODISC          2018             12
# 9999   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
# Filtern nach usageclass: Physical und materialtype ungleich BOOK
checkouts.loc[(checkouts['usageclass'] == "Physical") & (checkouts['materialtype'] != "BOOK")]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 2      Physical      Horizon    VIDEODISC          2018             12
# 8      Physical      Horizon    VIDEODISC          2018             12
# 11     Physical      Horizon    SOUNDDISC          2018             12
# 16     Physical      Horizon    VIDEODISC          2018             12
# 22     Physical      Horizon    VIDEODISC          2018             12
# ...         ...          ...          ...           ...            ...
# 9992   Physical      Horizon    SOUNDDISC          2018             12
# 9993   Physical      Horizon    SOUNDDISC          2018             12
# 9995   Physical      Horizon    SOUNDDISC          2018             12
# 9996   Physical      Horizon    VIDEODISC          2018             12
# 9998   Physical      Horizon    VIDEODISC          2018             12
#
#       checkouts                                              title  \
# ...
